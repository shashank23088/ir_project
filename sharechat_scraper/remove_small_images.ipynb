# %%
import os
from PIL import Image

# %%
def remove_small_images(directory):
    for filename in os.listdir(directory):
        filepath = os.path.join(directory, filename)
        try:
            with Image.open(filepath) as img:
                width, height = img.size
                if width <= 128 or height <= 128:
                    os.remove(filepath)
                    print(f"Removed: {filename} - Size: {width}x{height}")
        except Exception as e:
            print(f"Error processing {filename}: {e}")

# %%
remove_small_images("data/5ZEBpp/") #lew5Am, m6d09W
# Out:
# Removed: brlebQn.jpeg - Size: 128x128
# Removed: bqxNGMP.jpeg - Size: 128x128
# Removed: 3jj9l7j.jpeg - Size: 128x128
# Removed: b1blz6Q.jpeg - Size: 128x128
# Removed: rvaxyX3.jpeg - Size: 128x128
# Removed: 3PAnKam.jpeg - Size: 50x50
# Removed: 3N1wgEBy.jpeg - Size: 128x128
# Removed: 3a3x9bK.jpeg - Size: 128x128
# Removed: g14b3VA.jpeg - Size: 128x128
# Removed: 35k0yrw.jpeg - Size: 128x128
# Removed: rRRVmz1.jpeg - Size: 128x128
# Removed: rKXV1ww.jpeg - Size: 128x128
# Removed: brxk3Vy.jpeg - Size: 128x128
# Removed: r5mawe1.jpeg - Size: 128x128
# Removed: bgj1ZB3.jpeg - Size: 128x128
# Removed: rZKpwQE.jpeg - Size: 128x128
# Removed: rnApzp7.jpeg - Size: 50x50
# Removed: dXyK1RE.jpg - Size: 50x50
# Removed: r5AabME.jpeg - Size: 128x128
# Removed: dOv9lAD.jpg - Size: 50x50
# Removed: 3A4BAO3.jpeg - Size: 50x50
# Removed: bXgDq3a.jpeg - Size: 128x128
# Removed: rZXJn73.jpeg - Size: 128x128
# Removed: bm4AqyD.jpeg - Size: 128x128
# Removed: bPdNeJQ.jpeg - Size: 128x128
# ...

# %%
remove_small_images("data/lew5Am/") #lew5Am, m6d09W
# Out:
# Removed: bvOgxmvJ.png - Size: 128x128
# Removed: r170y967.jpeg - Size: 128x128
# Removed: g7mOVPQ.jpeg - Size: 128x128
# Removed: r1Www1ld.jpeg - Size: 128x128
# Removed: bZpzQ8a.jpeg - Size: 128x128
# Removed: bvQjmnAa.jpg - Size: 128x128
# Removed: bvmVpma1.jpeg - Size: 128x128
# Removed: 33Aa5Qn.jpeg - Size: 50x50
# Removed: bZQJQey.jpeg - Size: 128x128
# Removed: bXGx7OQ.jpeg - Size: 128x128
# Removed: bv98b79n.jpeg - Size: 128x128
# Removed: bvyGW9GJ.jpeg - Size: 128x128
# Removed: 3Nw3J0am.jpeg - Size: 50x50
# Removed: bv7Pg5A1.jpeg - Size: 128x128
# Removed: g75kMEq.jpeg - Size: 128x128
# Removed: bvQPvlrX.jpeg - Size: 128x128
# Removed: bBRWmPX.jpeg - Size: 128x128
# Removed: bK1gyry.jpeg - Size: 128x128
# Removed: bvmRk0lO.jpeg - Size: 128x128
# Removed: bvGBBQ71.jpeg - Size: 128x128
# Removed: grkEQ8bA.jpeg - Size: 128x128
# Removed: bvvzKxl3.jpg - Size: 50x50
# Removed: bD9jMGy.jpeg - Size: 128x128
# Removed: r1gb7VP7.jpeg - Size: 50x50
# ...

# %%
remove_small_images("data/m6d09W/") #lew5Am, m6d09W
# Out:
# Removed: brlebQn.jpeg - Size: 128x128
# Removed: grO4xNve.jpeg - Size: 128x128
# Removed: gOyR9MA.jpeg - Size: 128x128
# Removed: 3gEzEJ5.jpeg - Size: 128x128
# Removed: ggvZGbq.jpeg - Size: 128x128
# Removed: g1rM9yA.jpeg - Size: 128x128
# Removed: r1GgydE3.jpeg - Size: 50x38
# Removed: 3Q3lDEw.jpeg - Size: 128x128
# Removed: 3lmdByn.jpeg - Size: 128x128
# Removed: bm4V0PJ.jpeg - Size: 128x128
# Removed: grkx5PO6.jpeg - Size: 128x128
# Removed: grb709Rz.jpeg - Size: 128x128
# Removed: grzDWea6.jpeg - Size: 128x128
# Removed: gWvBZK1.jpeg - Size: 128x128
# Removed: bR9ya13.jpeg - Size: 50x50
# Removed: dbGMb6E.jpg - Size: 50x50
# Removed: g7VeQve.png - Size: 128x128
# Removed: g735KWz.jpeg - Size: 128x128
# Removed: 3l7VNJ3.jpeg - Size: 128x128
# Removed: gDQzbOq.jpeg - Size: 128x128
# Removed: bRy5J8a.jpeg - Size: 128x128
# Removed: rJ3VAVw.png - Size: 97x97
# Removed: gr01ONZe.jpeg - Size: 128x128
# Removed: bRnvRWD.jpeg - Size: 128x128
# Removed: bB1B1Ja.jpeg - Size: 128x128
# ...
