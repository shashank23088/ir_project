# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import os
# Out:
# /home/shashankgsharma/anaconda3/lib/python3.11/site-packages/pandas/core/arrays/masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# # 1. Sentiment Analysis

# %%
# generate csv from data

pd.read_csv('Narendra Modi.csv')
# Out:
#     Unnamed: 0       pos       neu       neg  likes  views
# 0            0  0.087666  0.005822  0.000000      6     73
# 1            1  0.001128  0.001384  0.005697     24     67
# 2            2  0.000000  0.086034  0.219716     15   1200
# 3            3  0.000000  0.145261  0.000000     10   1100
# 4            4  0.678788  1.000000  0.000000      3   2400
# ..         ...       ...       ...       ...    ...    ...
# 62          62  0.018101  0.006793  0.004173     11     88
# 63          63  0.011216  0.000000  0.006098     32     81
# 64          64  0.034568  0.055241  0.110106     21   1100
# 65          65  0.000000  0.149716  0.000000     15   1700
# 66          66  0.015354  0.023465  0.000000     55   1100
#
# [67 rows x 6 columns]

# %%
pd.read_csv('Rahul Gandhi.csv')
# Out:
#     Unnamed: 0       pos       neu       neg  likes  views
# 0            0  0.000000  0.059485  0.000000    200   6200
# 1            1  0.000000  0.265033  0.000000     12   1500
# 2            2  0.000000  0.058079  0.000000     56   1700
# 3            3  0.083564  0.406948  0.891288     32   7200
# 4            4  0.019040  0.031167  0.151154     84   2100
# 5            5  0.000000  0.325700  0.000000    328  50100
# 6            6  0.013575  0.048524  0.447599     56   2100
# 7            7  0.025387  0.059674  0.000000     74   2700
# 8            8  0.002715  0.002029  0.010320     16     88
# 9            9  0.125579  0.355605  0.983440     50  10600
# 10          10  0.000000  0.073162  0.000000     51   1900
# 11          11  0.000000  0.000413  0.038980     15     71
# 12          12  0.000000  0.077840  0.000000     33   1300
# 13          13  0.000000  1.000000  0.000000     18   8300
# 14          14  0.059625  0.182332  0.750385    540  61700
# ...

# %%
pd.read_csv('Arvind Kejrival.csv')
# Out:
#     Unnamed: 0       pos       neu       neg  likes  views
# 0            0  0.191992  0.176888  0.013459     19   1100
# 1            1  0.635682  0.309967  0.040825     11   1200
# 2            2  0.000000  0.146176  0.000000     28   1200
# 3            3  0.363076  0.064838  0.000000     61   1700
# 4            4  0.029799  0.042160  0.014073      5     85
# 5            5  0.000000  0.231668  0.000000     18   1200
# 6            6  0.245760  0.174705  0.020624    161   9600
# 7            7  0.000000  0.000000  0.001368     36     86
# 8            8  0.000000  0.006292  0.000000     20     78
# 9            9  0.177579  0.134990  0.009475     31   1400
# 10          10  0.147388  0.156264  0.038431     18   1000
# 11          11  0.000000  0.134246  0.000000     43   1700
# 12          12  0.000000  0.171823  0.000000     28   1400
# 13          13  0.000000  0.009820  0.000000     17     83
# 14          14  0.000000  0.161141  0.123184     16   1100
# ...
